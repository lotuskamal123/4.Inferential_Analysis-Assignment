# %%
import pandas as pd

# %%
# pip install --upgrade seaborn pandas

# %%
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
print("No.of Rows={0} and columns={1}".format(dataset.shape[0],dataset.shape[1]))
# Out:
# No.of Rows=215 and columns=15

# %%
dataset=dataset.drop('sl_no',axis=1)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # 1)Replace the NaN values with correct value. And justify why you have chosen the same.

# %%
dataset.isnull().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
# Replace missing value
dataset.fillna({'salary':0},inplace=True)

# %%
dataset.isnull().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Reason for missing values occur Here,Students status is not placed,So they didn't got salary
#Solution-1: Filling with correct reason,In this case we can't apply cenral Tendency because 
             #if we find out mean,median,average means we fill salary with some values.
#Solution-2:So, that students status considered as Placed and that dataset original information was totally changed.
#Solution-3: we replace the missing values with '0' So,that we got Dataset without any information Loss.

# %% [markdown]
# # 2) How many of them are not placed?

# %%
NP=dataset[dataset["status"]=="Not Placed"]

# %%
NP.shape[0]
# Out:
# 67

# %% [markdown]
# # 3)Find the reason for non placement from the dataset?

# %%
NP=dataset[dataset["status"]=="Not Placed"]

# %%
NP
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
#Solution: As far my understand from this plot non placement students are got low percentage compared with placed student.

# %%
from univariate import univar
quan,qual=univar.QuanQual(dataset)

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
descriptive=pd.DataFrame(index=["Median"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Median"]=dataset[columnName].median()
descriptive
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_8892\1652359957.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Median"]=dataset[columnName].median()
# ...

# %% [markdown]
# # 4)What kind of relation between salary and mba_p

# %%
# Two columns between both means we are find out correlation method.

# %%
dataset.corr(numeric_only=True)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# Solution:it's a positive correlation

# %% [markdown]
# # 5)Which specialization is getting minimum salary?

# %%
sns.stripplot(x="specialisation",y="salary",data=dataset)
plt.show()

# %%
# Solution: From dataset Mkt&HR specialisation is minimum salary.

# %% [markdown]
# # 6)How many of them getting above 500000 salary?

# %%
salary=dataset[dataset.salary>500000]

# %%
salary
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 119      M   60.8  Central  68.40  Central  Commerce      64.6  Comm&Mgmt
# 150      M   71.0  Central  58.66  Central   Science      58.0   Sci&Tech
# 177      F   73.0  Central  97.00   Others  Commerce      79.0  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status    salary
# 119    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
# Solution: Three student are got above 500000 salary.

# %% [markdown]
# # 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
# Solution:Here,pvalue > 5% So,we Accept Alternate hypothesis.

# %% [markdown]
# # 8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_ind
degree_t=dataset[dataset['degree_t']=='Sci&Tech']['salary']
speci=dataset[dataset['specialisation']=='Mkt&HR']['salary']
ttest_ind(degree_t,speci)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471179, df=152.0)

# %%
# Solution: There is no similer for both degree and specialisation with the salary.Here,pvalue=0.00789 Reject null hypothesis h0.

# %% [markdown]
# # 9)Convert the normal distribution to standard normal distribution for salary column.

# %%
def snd(dataset):
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    values=[i for i in dataset]
    z_score=[((j-mean)/std) for j in values]
    sns.distplot(z_score,kde=True)
    print(sum(z_score)/len(z_score))
    plt.show()

# %%
snd(dataset['salary'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_8892\2917538540.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)
# -8.881784197001253e-17

# %%
# Solution: mean,median mode are not same so we got curve like this.so salary columns have different salaries.

# %% [markdown]
# # 10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    import matplotlib.pyplot as plt
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'Red'},color='blue')
    pyplot.axvline(startrange,color='green')
    pyplot.axvline(endrange,color='green')
    sample=dataset
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f,Standard Deviation=%.3f' %(sample_mean,sample_std))
    dist=norm(sample_mean,sample_std)
    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    plt.plot(prob, norm.pdf(prob, sample_mean, sample_std))
    plt.show()
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    
    return prob

# %%
get_pdf_probability(dataset['salary'], 700000,900000)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_8892\914235277.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'Red'},color='blue')
# Mean=198702.326,Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974901
# 0.0005973310593974901

# %% [markdown]
# # 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_ind
degree_t=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
degree_t1=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
ttest_ind(degree_t,degree_t1)
# Out:
# TtestResult(statistic=4.532000225151251, pvalue=1.4289217003775636e-05, df=116.0)

# %%
# Solution: There is no similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p.

# %% [markdown]
# # 12)Which parameter is highly correlated with salary?

# %%
dataset.corr(numeric_only=True)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# Solution: ssc_p is highest correlated with salary.

# %% [markdown]
# # 13) plot any useful graph and explain it.

# %%
sns.pairplot(dataset,hue='degree_t',diag_kind='kde',kind='scatter',palette='husl')
plt.show()

# %%
# Solution: As far my understand from this plot Comm&Mngt degree has good percentage compared with Sci&Tech.
